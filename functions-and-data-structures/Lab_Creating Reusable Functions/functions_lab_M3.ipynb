# %% [markdown]
# # Module 3 Lab: Creating Reusable Functions

# %%
import pandas as pd

# %% [markdown]
# ## Sample dataset

# %%
data = [
    {"Name": "Alpha", "value": 10, "category": "A"},
    {"Name": "Beta", "value": None, "category": "A"},
    {"Name": "Gamma", "value": 12, "category": "B"},
]

# %% [markdown]
# ## TODO: Write your functions below
