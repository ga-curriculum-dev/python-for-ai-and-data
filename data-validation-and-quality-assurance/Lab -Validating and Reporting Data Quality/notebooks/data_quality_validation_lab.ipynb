# %% [markdown]
# # Data Quality Validation Lab
#
# Starter Notebook

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv('../data/dataset.csv')
df.head()

# %% [markdown]
# ## TODO: Inspect data quality
# - Check missing values
# - Check duplicates
# - Inspect ranges

# %%
# Your code here

# %% [markdown]
# ## TODO: Apply validation checks and assertions

# %%
# Your code here

# %% [markdown]
# ## TODO: Save validated dataset to output/

# %%
# Your code here
