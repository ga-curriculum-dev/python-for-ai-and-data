# %% [markdown]
# # Module 4: File Formats and Data I/O (Solution)

# %%
from pathlib import Path
import csv
import json
import pandas as pd

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"
OUTPUT_DIR = PROJECT_ROOT / "output"

DATA_DIR, OUTPUT_DIR

# %%
csv_file = DATA_DIR / "sample_people.csv"

people = []
with open(csv_file, "r", encoding="utf-8") as f:
    reader = csv.DictReader(f)
    for row in reader:
        row["id"] = int(row["id"])
        row["age"] = int(row["age"])
        people.append(row)

people

# %%
config_file = DATA_DIR / "sample_config.json"
with open(config_file, "r", encoding="utf-8") as f:
    config = json.load(f)

config

# %%
filtered = [
    p for p in people
    if p["age"] >= config["min_age"]
    and p["city"] in config["allowed_cities"]
]

filtered

# %%
output_csv = OUTPUT_DIR / config["output_filename"]

with open(output_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["id","name","age","city"])
    writer.writeheader()
    writer.writerows(filtered)

output_csv

# %%
df = pd.read_csv(csv_file)
df_filtered = df[df["age"] >= config["min_age"]]
df_filtered.to_csv(OUTPUT_DIR / "people_filtered_pandas.csv", index=False)
df_filtered
